# %%
import os

# %%
# %pwd
# Out:
# '/home/uday/Practise/github_personal/pothole_detection/pothole_detection/research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/home/uday/Practise/github_personal/pothole_detection/pothole_detection'

# %%
from pathlib import Path
from dataclasses import dataclass

# %%
@dataclass(frozen=True)
class CustomTrainingConfig:
    root_dir: Path
    trained_weights_dir: Path
    params_task: str
    params_mode: str
    params_model: Path
    params_imgsz: int
    params_data: Path
    params_epochs: int
    params_batch: int
    params_name: str
    params_project: Path
    base_weight_dir: str
    params_resume: str

# %%
from potholeDetector.constants import *
from potholeDetector.utils.common import *

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
    
    def get_custom_training_config(self) -> CustomTrainingConfig:
        config_training = self.config.training
        config_prepare_base_model = self.config.prepare_base_model
        params = self.params.training
        create_directories([
            self.config.artifacts_root, 
            config_training.root_dir, 
            config_training.trained_model_dir
            ])
        # model_path = os.path.join(config_prepare_base_model.weights_dir,params.model)
        # print(model_path)
        custom_training_config = CustomTrainingConfig(
            root_dir=Path(config_training.root_dir),
            trained_weights_dir=Path(config_training.trained_model_dir),
            params_task=params.task,
            params_mode=params.mode,
            params_model=params.model,
            params_imgsz=params.imgsz,
            params_data=Path(params.data),
            params_epochs=params.epochs,
            params_batch=params.batch,
            params_name=params.name,
            params_project=Path(params.project),
            base_weight_dir=config_prepare_base_model.weights_dir,  
            params_resume=params.resume,    
        )

        return custom_training_config

# %%
from ultralytics import YOLO

# %%
class CustomTraining:
    def __init__(self, config: CustomTrainingConfig):
        self.config = config
    
    def train(self):
        # Load the YOLOv8 model.
        # base_model_path = os.path.join(self.config.base_weight_dir, self.config.params_model)
        model = YOLO(self.config.params_model)
        # model = YOLO('yolov8n.pt')


        # Train the model.
        # yolo task=detect mode=train model=yolov8n.pt imgsz=1280 data=pothole_v8.yaml epochs=50 batch=8 name=yolov8n_v8_50e
        results = model.train(
            task=self.config.params_task,
            mode=self.config.params_mode,
            # model=self.config.params_model,
            imgsz=self.config.params_imgsz,
            data=self.config.params_data,
            epochs=self.config.params_epochs,
            batch=self.config.params_batch,
            name=self.config.params_name,
            project=self.config.params_project,
            resume=self.config.params_resume,
        )

# %%
try:
    config = ConfigurationManager()
    custom_training_config = config.get_custom_training_config()
    print(custom_training_config)
    custom_training = CustomTraining(config=custom_training_config)
    custom_training.train()
except Exception as e:
    raise e
# Out:
# [2023-07-27 01:10:51,031: INFO:common:YAML file: config/config.yaml loaded successfully]
# [2023-07-27 01:10:51,034: INFO:common:YAML file: params.yaml loaded successfully]
# [2023-07-27 01:10:51,035: INFO:common:Created directory at: artifacts]
# [2023-07-27 01:10:51,036: INFO:common:Created directory at: artifacts/training]
# [2023-07-27 01:10:51,036: INFO:common:Created directory at: artifacts/training/runs]
# New https://pypi.org/project/ultralytics/8.0.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.135 🚀 Python-3.10.6 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# yolo/engine/trainer: task=detect, mode=train, model=artifacts/training/runs/yolov8n_v8_1e7/weights/best.pt, data=pothole_v8.yaml, epochs=1, patience=50, batch=4, imgsz=1280, save=True, save_period=-1, cache=False, device=None, workers=8, project=/home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs, name=yolov8n_v8_1e, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=/home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs/yolov8n_v8_1e8
#
#                    from  n    params  module                                       arguments
# CustomTrainingConfig(root_dir=PosixPath('artifacts/training'), trained_weights_dir=PosixPath('artifacts/training/runs'), params_task='detect', params_mode='train', params_model='artifacts/training/runs/yolov8n_v8_1e7/weights/best.pt', params_imgsz=1280, params_data=PosixPath('pothole_v8.yaml'), params_epochs=1, params_batch=4, params_name='yolov8n_v8_1e', params_project=PosixPath('/home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs'), base_weight_dir='artifacts/prepare_base_model/weights', params_resume=False)
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients
#
# Transferred 355/355 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/labels.cache... 6960 images, 8 backgrounds, 0 corrupt: 100%|██████████| 6960/6960 [00:00<?, ?it/s]
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0012012.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0052120.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0063926.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0063927.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064103.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064146.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064186.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064187.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064409.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064410.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064411.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064412.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064413.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064414.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064415.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064416.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064417.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064418.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064419.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064420.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064426.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064427.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064428.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064429.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064430.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064431.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064432.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064433.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064434.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064438.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064439.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064440.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064441.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064442.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064443.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064444.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064445.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064446.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064447.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064448.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064449.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064450.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064451.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064452.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064453.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064454.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064461.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064462.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064489.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064490.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064511.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064517.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064518.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064519.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064520.jpg: 7 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064521.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064522.jpg: 8 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064523.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064524.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064525.jpg: 8 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064526.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064527.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064528.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064529.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064530.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064532.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064533.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064535.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064536.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064538.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064543.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064544.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064546.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064547.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064548.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064549.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064550.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064556.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064557.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064558.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064559.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064560.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064561.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064562.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064574.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064575.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064576.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064577.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064581.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064582.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064589.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064590.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064611.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064617.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064621.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064627.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064628.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064631.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064702.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064710.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064714.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064715.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064716.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064717.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064722.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064723.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064724.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064725.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064738.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064739.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064743.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064754.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064755.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064779.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064780.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064784.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064795.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064796.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064797.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064805.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064806.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064807.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064808.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064809.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064810.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064811.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064822.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064823.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064850.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064859.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064860.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064861.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064865.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064866.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064867.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0064868.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0307782.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0459767.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/train/images/G0459768.jpg: 2 duplicate labels removed
# val: Scanning /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/labels.cache... 271 images, 0 backgrounds, 0 corrupt: 100%|██████████| 271/271 [00:00<?, ?it/s]
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011603.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011614.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011616.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011661.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011662.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011664.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011677.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011678.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011705.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011769.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011772.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011773.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011876.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011878.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011881.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011966.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011968.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011969.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011970.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011978.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011981.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/data_ingestion/dataset/valid/images/G0011982.jpg: 1 duplicate labels removed
# Plotting labels to /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs/yolov8n_v8_1e8/labels.jpg...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 4 dataloader workers
# Logging results to /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs/yolov8n_v8_1e8
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1      2.21G       2.04      2.362      1.791         17       1280: 100%|██████████| 1740/1740 [02:52<00:00, 10.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 34/34 [00:03<00:00, 10.81it/s]
#                    all        271        716      0.412      0.237      0.233     0.0985
#
# 1 epochs completed in 0.049 hours.
# Optimizer stripped from /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs/yolov8n_v8_1e8/weights/last.pt, 6.3MB
# Optimizer stripped from /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs/yolov8n_v8_1e8/weights/best.pt, 6.3MB
#
# Validating /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs/yolov8n_v8_1e8/weights/best.pt...
# Ultralytics YOLOv8.0.135 🚀 Python-3.10.6 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 34/34 [00:02<00:00, 16.01it/s]
#                    all        271        716      0.416      0.237      0.234     0.0984
# Speed: 0.5ms preprocess, 3.4ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/uday/Practise/github_personal/pothole_detection/pothole_detection/artifacts/training/runs/yolov8n_v8_1e8
